# %% [markdown]
# # Étape 1 : visualisation simple des flux 1789
#
# D'après la doc de kepler : https://docs.kepler.gl/docs/keplergl-jupyter#demo-notebooks

# %%
# Load an empty map
from keplergl import KeplerGl
#from dunkerquesprint import Portic
#import pandas as pd

#portic_client = Portic()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [10], in <module>
#       1 # Load an empty map
# ----> 2 from keplergl import KeplerGl
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keplergl/__init__.py:3, in <module>
#       1 from ._version import version_info, __version__
# ----> 3 from .keplergl import *
#       5 def _jupyter_nbextension_paths():
#       6     return [{
#       7         'section': 'notebook',
#       8         'src': 'static',
#       9         'dest': 'keplergl-jupyter',
#      10         'require': 'keplergl-jupyter/extension'
#      11     }]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keplergl/keplergl.py:5, in <module>
#       3 from traitlets import Unicode, Dict, Int, validate, TraitError
#       4 import pandas as pd
# ----> 5 import geopandas
#       6 import shapely.wkt
#       7 import json
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/geopandas/__init__.py:1, in <module>
# ----> 1 from geopandas._config import options  # noqa
#       3 from geopandas.geoseries import GeoSeries  # noqa
#       4 from geopandas.geodataframe import GeoDataFrame  # noqa
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/geopandas/_config.py:109, in <module>
#     102     import geopandas._compat as compat
#     104     compat.set_use_pygeos(value)
#     107 use_pygeos = Option(
#     108     key="use_pygeos",
# --> 109     default_value=_default_use_pygeos(),
#     110     doc=(
#     111         "Whether to use PyGEOS to speed up spatial operations. The default is True "
#     112         "if PyGEOS is installed, and follows the USE_PYGEOS environment variable "
#     113         "if set."
#     114     ),
#     115     validator=_validate_bool,
#     116     callback=_callback_use_pygeos,
#     117 )
#     120 options = Options({"display_precision": display_precision, "use_pygeos": use_pygeos})
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/geopandas/_config.py:95, in _default_use_pygeos()
#      94 def _default_use_pygeos():
# ---> 95     import geopandas._compat as compat
#      97     return compat.USE_PYGEOS
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/geopandas/_compat.py:11, in <module>
#       9 import pyproj
#      10 import shapely
# ---> 11 import shapely.geos
#      14 # -----------------------------------------------------------------------------
#      15 # pandas compat
#      16 # -----------------------------------------------------------------------------
#      18 PANDAS_GE_10 = str(pd.__version__) >= LooseVersion("1.0.0")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/shapely/geos.py:160, in <module>
#     149     else:
#     150         alt_paths = [
#     151             # The Framework build from Kyng Chaos
#     152             "/Library/Frameworks/GEOS.framework/Versions/Current/GEOS",
#    (...)
#     158             '/opt/homebrew/lib/libgeos_c.dylib',
#     159         ]
# --> 160     _lgeos = load_dll('geos_c', fallbacks=alt_paths)
#     162 free = CDLL(None).free
#     163 free.argtypes = [c_void_p]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/shapely/geos.py:54, in load_dll(libname, fallbacks, mode)
#      51     return dll
#      52 else:
#      53     # No shared library was loaded. Raise OSError.
# ---> 54     raise OSError(
#      55         "Could not find lib {} or load any of its variants {}.".format(
#      56             libname, fallbacks or []))
#
# OSError: Could not find lib geos_c or load any of its variants ['/Library/Frameworks/GEOS.framework/Versions/Current/GEOS', '/opt/local/lib/libgeos_c.dylib', '/usr/local/lib/libgeos_c.dylib', '/opt/homebrew/lib/libgeos_c.dylib'].

# %%
travels = portic_client.get_flows(year=1789)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <module>
# ----> 1 travels = portic_client.get_flows(year=1789)
#
# NameError: name 'portic_client' is not defined

# %%
# setting kepler config
config = {
    'version': 'v1',
    'config': {
        # centering the map on the region
        'mapState': {
            'latitude': 45.6876849,
            'longitude': -1.15,
            'zoom': 5.2
        }
    }
}
# fixing data types issues
travels_clean = []
for travel in travels:
    final_travel = travel.copy()
    COORDS_KEYS = ["departure_latitude", "departure_longitude", "destination_latitude", "destination_longitude"]
    for key in COORDS_KEYS:
        final_travel[key] = float(final_travel[key])
    travels_clean.append(final_travel)
# creating a dataframe with all the travels
df = pd.DataFrame(travels_clean)

flux_map = KeplerGl(config=config, data={'data_1': df})
flux_map

# %% [markdown]
# # Étape 2 : filtrer sur les flux du datasprint
#
# Je filtre les flux à source_subset = Poitou_1789

# %%
travels_clean = []
for travel in travels:
    final_travel = travel.copy()
    if final_travel["source_subset"] == "Poitou_1789":
        COORDS_KEYS = ["departure_latitude", "departure_longitude", "destination_latitude", "destination_longitude"]
        for key in COORDS_KEYS:
            final_travel[key] = float(final_travel[key])
        travels_clean.append(final_travel)
# creating a dataframe with all the travels
df = pd.DataFrame(travels_clean)

flux_map = KeplerGl(config=config, height=800, data={'data_1': df})
flux_map

# %% [markdown]
# # Test de vue en 3D
# Je vais sur la vue qui m'intéresse puis je copie la config

# %%
config =   {
  "version": "v1",
  "config": {
    "visState": {
      "filters": [],
      "layers": [
        {
          "id": "7huoiug",
          "type": "point",
          "config": {
            "dataId": "data_1",
            "label": "departure",
            "color": [
              18,
              147,
              154
            ],
            "columns": {
              "lat": "departure_latitude",
              "lng": "departure_longitude",
              "altitude": None
            },
            "isVisible": False,
            "visConfig": {
              "radius": 10,
              "fixedRadius": False,
              "opacity": 0.8,
              "outline": False,
              "thickness": 2,
              "strokeColor": None,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "strokeColorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "radiusRange": [
                0,
                50
              ],
              "filled": True
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "strokeColorField": None,
            "strokeColorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        },
        {
          "id": "bscngi2",
          "type": "point",
          "config": {
            "dataId": "data_1",
            "label": "destination",
            "color": [
              221,
              178,
              124
            ],
            "columns": {
              "lat": "destination_latitude",
              "lng": "destination_longitude",
              "altitude": None
            },
            "isVisible": False,
            "visConfig": {
              "radius": 10,
              "fixedRadius": False,
              "opacity": 0.8,
              "outline": False,
              "thickness": 2,
              "strokeColor": None,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "strokeColorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "radiusRange": [
                0,
                50
              ],
              "filled": True
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "strokeColorField": None,
            "strokeColorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        },
        {
          "id": "r0qwsr",
          "type": "point",
          "config": {
            "dataId": "data_1",
            "label": "homeport",
            "color": [
              136,
              87,
              44
            ],
            "columns": {
              "lat": "homeport_latitude",
              "lng": "homeport_longitude",
              "altitude": None
            },
            "isVisible": False,
            "visConfig": {
              "radius": 10,
              "fixedRadius": False,
              "opacity": 0.8,
              "outline": False,
              "thickness": 2,
              "strokeColor": None,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "strokeColorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "radiusRange": [
                0,
                50
              ],
              "filled": True
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "strokeColorField": None,
            "strokeColorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        },
        {
          "id": "11ipmk",
          "type": "arc",
          "config": {
            "dataId": "data_1",
            "label": "departure -> destination arc",
            "color": [
              146,
              38,
              198
            ],
            "columns": {
              "lat0": "departure_latitude",
              "lng0": "departure_longitude",
              "lat1": "destination_latitude",
              "lng1": "destination_longitude"
            },
            "isVisible": False,
            "visConfig": {
              "opacity": 0.8,
              "thickness": 2,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "sizeRange": [
                0,
                10
              ],
              "targetColor": None
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        },
        {
          "id": "c39f66f",
          "type": "arc",
          "config": {
            "dataId": "data_1",
            "label": "departure -> destination line",
            "color": [
              255,
              153,
              31
            ],
            "columns": {
              "lat0": "departure_latitude",
              "lng0": "departure_longitude",
              "lat1": "destination_latitude",
              "lng1": "destination_longitude"
            },
            "isVisible": True,
            "visConfig": {
              "opacity": 0.8,
              "thickness": 2,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "sizeRange": [
                0,
                10
              ],
              "targetColor": [
                125,
                177,
                227
              ]
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        }
      ],
      "interactionConfig": {
        "tooltip": {
          "fieldsToShow": {
            "data_1": [
              {
                "name": "travel_id",
                "format": None
              },
              {
                "name": "distance_dep_dest",
                "format": None
              },
              {
                "name": "distance_homeport_dep",
                "format": None
              },
              {
                "name": "departure",
                "format": None
              },
              {
                "name": "departure_fr",
                "format": None
              }
            ]
          },
          "compareMode": False,
          "compareType": "absolute",
          "enabled": True
        },
        "brush": {
          "size": 0.5,
          "enabled": False
        },
        "geocoder": {
          "enabled": False
        },
        "coordinate": {
          "enabled": False
        }
      },
      "layerBlending": "normal",
      "splitMaps": [],
      "animationConfig": {
        "currentTime": None,
        "speed": 1
      }
    },
    "mapState": {
      "bearing": 24,
      "dragRotate": True,
      "latitude": 35.2083646354612,
      "longitude": -69.3342670698591,
      "pitch": 50,
      "zoom": 1.9795387675756313,
      "isSplit": False
    },
    "mapStyle": {
      "styleType": "light",
      "topLayerGroups": {},
      "visibleLayerGroups": {
        "label": False,
        "road": False,
        "border": False,
        "building": False,
        "water": True,
        "land": False,
        "3d building": False
      },
      "threeDBuildingColor": [
        218.82023004728686,
        223.47597962276103,
        223.47597962276103
      ],
      "mapStyles": {}
    }
  }
}

flux_map = KeplerGl(config=config, height=800, data={'data_1': df})
flux_map

# %%
config = {
  "version": "v1",
  "config": {
    "visState": {
      "filters": [],
      "layers": [
        {
          "id": "20i5e6b",
          "type": "point",
          "config": {
            "dataId": "data_1",
            "label": "departure",
            "color": [
              241,
              92,
              23
            ],
            "columns": {
              "lat": "departure_latitude",
              "lng": "departure_longitude",
              "altitude": None
            },
            "isVisible": True,
            "visConfig": {
              "radius": 10,
              "fixedRadius": False,
              "opacity": 0.8,
              "outline": False,
              "thickness": 2,
              "strokeColor": None,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "strokeColorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "radiusRange": [
                0,
                50
              ],
              "filled": True
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "strokeColorField": None,
            "strokeColorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        },
        {
          "id": "qtzpdyc",
          "type": "point",
          "config": {
            "dataId": "data_1",
            "label": "destination",
            "color": [
              34,
              63,
              154
            ],
            "columns": {
              "lat": "destination_latitude",
              "lng": "destination_longitude",
              "altitude": None
            },
            "isVisible": False,
            "visConfig": {
              "radius": 10,
              "fixedRadius": False,
              "opacity": 0.8,
              "outline": False,
              "thickness": 2,
              "strokeColor": None,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "strokeColorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "radiusRange": [
                0,
                50
              ],
              "filled": True
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "strokeColorField": None,
            "strokeColorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        },
        {
          "id": "g8ai3w8",
          "type": "point",
          "config": {
            "dataId": "data_1",
            "label": "homeport",
            "color": [
              218,
              112,
              191
            ],
            "columns": {
              "lat": "homeport_latitude",
              "lng": "homeport_longitude",
              "altitude": None
            },
            "isVisible": False,
            "visConfig": {
              "radius": 10,
              "fixedRadius": False,
              "opacity": 0.8,
              "outline": False,
              "thickness": 2,
              "strokeColor": None,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "strokeColorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "radiusRange": [
                0,
                50
              ],
              "filled": True
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "strokeColorField": None,
            "strokeColorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        },
        {
          "id": "6ohogte",
          "type": "arc",
          "config": {
            "dataId": "data_1",
            "label": "departure -> destination arc",
            "color": [
              146,
              38,
              198
            ],
            "columns": {
              "lat0": "departure_latitude",
              "lng0": "departure_longitude",
              "lat1": "destination_latitude",
              "lng1": "destination_longitude"
            },
            "isVisible": False,
            "visConfig": {
              "opacity": 0.8,
              "thickness": 2,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "sizeRange": [
                0,
                10
              ],
              "targetColor": None
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        },
        {
          "id": "7dn714",
          "type": "line",
          "config": {
            "dataId": "data_1",
            "label": "departure -> destination line",
            "color": [
              18,
              92,
              119
            ],
            "columns": {
              "lat0": "departure_latitude",
              "lng0": "departure_longitude",
              "lat1": "destination_latitude",
              "lng1": "destination_longitude"
            },
            "isVisible": False,
            "visConfig": {
              "opacity": 0.8,
              "thickness": 2,
              "colorRange": {
                "name": "Global Warming",
                "type": "sequential",
                "category": "Uber",
                "colors": [
                  "#5A1846",
                  "#900C3F",
                  "#C70039",
                  "#E3611C",
                  "#F1920E",
                  "#FFC300"
                ]
              },
              "sizeRange": [
                0,
                10
              ],
              "targetColor": None
            },
            "hidden": False,
            "textLabel": [
              {
                "field": None,
                "color": [
                  255,
                  255,
                  255
                ],
                "size": 18,
                "offset": [
                  0,
                  0
                ],
                "anchor": "start",
                "alignment": "center"
              }
            ]
          },
          "visualChannels": {
            "colorField": None,
            "colorScale": "quantile",
            "sizeField": None,
            "sizeScale": "linear"
          }
        }
      ],
      "interactionConfig": {
        "tooltip": {
          "fieldsToShow": {
            "data_1": [
              {
                "name": "travel_id",
                "format": None
              },
              {
                "name": "distance_dep_dest",
                "format": None
              },
              {
                "name": "distance_homeport_dep",
                "format": None
              },
              {
                "name": "departure",
                "format": None
              },
              {
                "name": "departure_fr",
                "format": None
              }
            ]
          },
          "compareMode": False,
          "compareType": "absolute",
          "enabled": True
        },
        "brush": {
          "size": 0.5,
          "enabled": False
        },
        "geocoder": {
          "enabled": False
        },
        "coordinate": {
          "enabled": False
        }
      },
      "layerBlending": "normal",
      "splitMaps": [],
      "animationConfig": {
        "currentTime": None,
        "speed": 1
      }
    },
    "mapState": {
      "bearing": 0,
      "dragRotate": False,
      "latitude": 45.836950192549764,
      "longitude": -1.2585136854558896,
      "pitch": 0,
      "zoom": 8.017897875842031,
      "isSplit": False
    },
    "mapStyle": {
      "styleType": "dark",
      "topLayerGroups": {},
      "visibleLayerGroups": {
        "label": True,
        "road": True,
        "border": False,
        "building": True,
        "water": True,
        "land": True,
        "3d building": False
      },
      "threeDBuildingColor": [
        9.665468314072013,
        17.18305478057247,
        31.1442867897876
      ],
      "mapStyles": {}
    }
  }
}

flux_map = KeplerGl(config=config, height=800, data={'data_1': df})
flux_map
